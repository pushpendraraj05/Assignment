# %% [markdown]
# ## MultiLinear Regression

# %% [markdown]
# ## ToyotaCorolla

# %%
#importing Library
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("D:\\assignment\\multi_liner_regression\\ToyotaCorolla.csv",encoding='unicode_escape')
print(data)
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %% [markdown]
# ## selecting the required column

# %%
c=data[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
#"Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
c
print(c)
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
c.isna().sum()
# Out:
# Price            0
# Age_08_04        0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %% [markdown]
# ## Preparation of model

# %%
import statsmodels.formula.api as smf
model=smf.ols("Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=c).fit()

# %%
model.params
# Out:
# Intercept       -5573.106358
# Age_08_04        -121.658402
# KM                 -0.020817
# HP                 31.680906
# cc                 -0.121100
# Doors              -1.616641
# Gears             594.319936
# Quarterly_Tax       3.949081
# Weight             16.958632
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Mon, 21 Nov 2022   Prob (F-statistic):               0.00
# Time:                        13:30:48   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
model.rsquared*100
# Out:
# 86.37627463428191

# %%
model.tvalues
# Out:
# Intercept        -3.948666
# Age_08_04       -46.511852
# KM              -16.621622
# HP               11.241018
# cc               -1.344222
# Doors            -0.040410
# Gears             3.016007
# Quarterly_Tax     3.014535
# Weight           15.879803
# dtype: float64

# %%
model.pvalues
# Out:
# Intercept         8.241949e-05
# Age_08_04        3.354724e-288
# KM                7.538439e-57
# HP                3.757218e-28
# cc                1.790902e-01
# Doors             9.677716e-01
# Gears             2.606549e-03
# Quarterly_Tax     2.619148e-03
# Weight            2.048576e-52
# dtype: float64

# %%
c.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
corr =c.corr()
#Plot figsize
fig, ax = plt.subplots(figsize=(8, 8))
import seaborn as sns

#Generate Heat Map, allow annotations and place floats in map
sns.heatmap(corr, cmap='magma', annot=True, fmt=".2f")
#Apply xticks
plt.xticks(range(len(corr.columns)), corr.columns);
#Apply yticks
plt.yticks(range(len(corr.columns)), corr.columns)
#show plot
plt.show()

# %%
import seaborn as sns
sns.pairplot(c)

# %% [markdown]
# ## Checking with Simple Linear Regression

# %% [markdown]
# ## Price~ Age

# %%
import statsmodels.formula.api as smf
model_age=smf.ols("Price~Age_08_04",data=c).fit()

# %%
model_age.params
# Out:
# Intercept    20294.058649
# Age_08_04     -170.933585
# dtype: float64

# %%
model_age.tvalues
# Out:
# Intercept    138.907847
# Age_08_04    -68.978267
# dtype: float64

# %%
model_age.pvalues
# Out:
# Intercept    0.0
# Age_08_04    0.0
# dtype: float64

# %% [markdown]
# ## Price~KM

# %%
model_km=smf.ols("Price~KM",data=c).fit()

# %%
model_km.params
# Out:
# Intercept    14508.140011
# KM              -0.055117
# dtype: float64

# %%
model_km.tvalues
# Out:
# Intercept    88.510378
# KM          -26.267601
# dtype: float64

# %%
model_km.pvalues
# Out:
# Intercept     0.000000e+00
# KM           1.757913e-124
# dtype: float64

# %% [markdown]
# ## Price~HP

# %%
model_hp=smf.ols("Price~HP",data=c).fit()

# %%
model_hp.params
# Out:
# Intercept    2990.276410
# HP             76.259988
# dtype: float64

# %%
model_hp.tvalues
# Out:
# Intercept     4.803134
# HP           12.567862
# dtype: float64

# %%
model_hp.pvalues
# Out:
# Intercept    1.725695e-06
# HP           1.926234e-34
# dtype: float64

# %% [markdown]
# ## Price~cc

# %%
model_cc=smf.ols("Price~cc",data=c).fit()

# %%
model_cc.params
# Out:
# Intercept    9027.554784
# cc              1.080168
# dtype: float64

# %%
model_cc.pvalues
# Out:
# Intercept    1.766912e-112
# cc            1.550808e-06
# dtype: float64

# %% [markdown]
# ## Price~Doors

# %%
model_d=smf.ols("Price~Doors",data=c).fit()

# %%
model_d.params
# Out:
# Intercept    7885.005835
# Doors         705.558636
# dtype: float64

# %%
model_d.pvalues
# Out:
# Intercept    1.094732e-73
# Doors        1.461237e-12
# dtype: float64

# %% [markdown]
# ## Price~ Gears

# %%
model_g=smf.ols("Price~Gears",data=c).fit()

# %%
model_g.params
# Out:
# Intercept    4628.065194
# Gears        1214.126127
# dtype: float64

# %%
model_g.pvalues
# Out:
# Intercept    0.069804
# Gears        0.016775
# dtype: float64

# %% [markdown]
# ## Price~Quarterly_Tax

# %%
model_q=smf.ols("Price~Quarterly_Tax",data=c).fit()

# %%
model_q.params
# Out:
# Intercept        9046.738225
# Quarterly_Tax      19.330082
# dtype: float64

# %%
model_q.pvalues
# Out:
# Intercept        1.532168e-246
# Quarterly_Tax     4.407393e-17
# dtype: float64

# %% [markdown]
# ## Price~Weight

# %%
model_w=smf.ols("Price~Weight",data=c).fit()

# %%
model_w.params
# Out:
# Intercept   -32215.197175
# Weight          40.044419
# dtype: float64

# %%
model_w.pvalues
# Out:
# Intercept     1.739508e-80
# Weight       1.630487e-130
# dtype: float64

# %% [markdown]
# ## Model Validation Technique

# %% [markdown]
# ## 1. Calculating VIF

# %% [markdown]
# ## VIF : 1/1-r^2 , it indicates the multicollinearity that exists in the set of variables that are involved in multiple regressions.

# %%
rsq_Price=smf.ols("Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=c).fit().rsquared
vif_Price=1/(1-rsq_Price)

# %%
vif_Price
# Out:
# 7.340136219395167

# %%
rsq_age=smf.ols("Age_08_04~Price+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=c).fit().rsquared
vif_age=1/(1-rsq_age)

# %%
vif_age
# Out:
# 4.741730371549739

# %%
rsq_km=smf.ols("KM~Age_08_04+Price+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=c).fit().rsquared

# %%
vif_km=1/(1-rsq_km)

# %%
vif_km
# Out:
# 2.0970552345918065

# %%
rsq_hp=smf.ols("HP~Age_08_04+Price+KM+cc+Doors+Gears+Quarterly_Tax+Weight",data=c).fit().rsquared
vif_hp=1/(1-rsq_hp)

# %%
vif_hp
# Out:
# 1.5451115796450527

# %%
rsq_cc=smf.ols("cc~Age_08_04+Price+KM+HP+Doors+Gears+Quarterly_Tax+Weight",data=c).fit().rsquared
vif_cc=1/(1-rsq_cc)

# %%
vif_cc
# Out:
# 1.165367761366548

# %%
rsq_door=smf.ols("Doors~Age_08_04+Price+KM+HP+cc++Gears+Quarterly_Tax+Weight",data=c).fit().rsquared
vif_door=1/(1-rsq_door)

# %%
vif_door
# Out:
# 1.1565765306116818

# %%
rsq_gr=smf.ols("Gears~Age_08_04+Price+KM+HP+cc+Doors++Quarterly_Tax+Weight",data=c).fit().rsquared
vif_gr=1/(1-rsq_gr)

# %%
vif_gr
# Out:
# 1.1057267416713281

# %%
rsq_qr=smf.ols("Quarterly_Tax~Age_08_04+Price+KM+HP+cc+Doors+Gears+Weight",data=c).fit().rsquared
vif_qr=1/(1-rsq_qr)

# %%
vif_qr
# Out:
# 2.326150465914314

# %%
rsq_wt=smf.ols("Weight~Age_08_04+Price+KM+HP+cc+Doors+Gears+Quarterly_Tax",data=c).fit().rsquared
vif_wt=1/(1-rsq_wt)

# %%
vif_wt
# Out:
# 2.961101646143709

# %% [markdown]
# ##  VIF determines the strength of the correlation between the independent variables. It is predicted by taking a variable and regressing it against every other variable.

# %%
#Sorting vif values in a data frame
d1={'Variables':['Price','Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight'],'VIF':[vif_Price,vif_age,vif_km,vif_hp,vif_cc,vif_door,vif_gr,vif_qr,vif_wt]}
vif_frame=pd.DataFrame(d1)
vif_frame
# Out:
#        Variables       VIF
# 0          Price  7.340136
# 1      Age_08_04  4.741730
# 2             KM  2.097055
# 3             HP  1.545112
# 4             cc  1.165368
# 5          Doors  1.156577
# 6          Gears  1.105727
# 7  Quarterly_Tax  2.326150
# 8         Weight  2.961102

# %% [markdown]
# ## non variable has VIF > 20, NO Collinearity, so
# ## Considering all variables in Regression Equations

# %% [markdown]
# ## 2. Residual Analysis
# ##       Test for Normality of Residual (Q-Q Plot)

# %%
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)
import statsmodels.api as sm
sm.qqplot(model.resid,line='q') # 'q' - A line is fit through the quartiles # line = '45'- to draw the 45-degree diagonal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
# Outlier detections
list(np.where(model.resid>6000))
# Out:
# [array([147, 523], dtype=int64)]

# %%
list(np.where(model.resid<-6000))
# Out:
# [array([221, 601, 960], dtype=int64)]

# %% [markdown]
# ## Residual Plot for Homoscedasticity
# ## (Residual Value Vs Fitted Value)

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# z=(x-mu)/sigma

# %%
plt.figure(figsize=(15,10))
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# ## Residual Vs Regressors
# ## (residual Vs Independent Values)

# %%
fig = plt.figure(figsize=(15,10))
fig = sm.graphics.plot_regress_exog(model, "Age_08_04", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,10))
fig = sm.graphics.plot_regress_exog(model, "KM", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,10))
fig = sm.graphics.plot_regress_exog(model, "HP", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,10))
fig = sm.graphics.plot_regress_exog(model, "cc", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,10))
fig = sm.graphics.plot_regress_exog(model, "Doors", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,10))
fig = sm.graphics.plot_regress_exog(model, "Gears", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,10))
fig = sm.graphics.plot_regress_exog(model, "Quarterly_Tax", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,10))
fig = sm.graphics.plot_regress_exog(model, "Weight", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# ## Detecting Influencers/Outliers
# ## Cook's Distance

# %%
from statsmodels.graphics.regressionplots import influence_plot

model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(c)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))
# Out:
# (80, 79.5201062414182)

# %%
# position of outliers at 80 at 79th index

# %% [markdown]
# ## High Influence Points

# %%
c.shape
# Out:
# (1436,)

# %%
# k= no of features
#n=no.s of observations

#leverage value of more than 3*((k + 1)/n) are treated as highly Influential Points

# %%
k=9
n=1436
leverage_cutoff=3*((k+1)/n)
leverage_cutoff
# Out:
# 0.020891364902506964

# %%
from statsmodels.graphics.regressionplots import influence_plot
import matplotlib.pyplot as plt

influence_plot(model,alhpa=0.5)

y=[i for i in range(-2,8)]
x=[leverage_cutoff for i in range(10)]
plt.plot(x,y,'r+')

plt.show()

# %% [markdown]
# ## Improvement of model

# %%
c1=c.copy()
c1
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
c2=c1.drop(c1.index[[80]],axis=0).reset_index(drop=True)
c2
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1430   7500         69  20544   86  1300      3      5             69    1025
# 1431  10845         72  19000   86  1300      3      5             69    1015
# 1432   8500         71  17016   86  1300      3      5             69    1015
# 1433   7250         70  16916   86  1300      3      5             69    1015
# 1434   6950         76      1  110  1600      5      5             19    1114
#
# [1435 rows x 9 columns]

# %% [markdown]
# ## Model Deletion & Analysing Final Model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
while model.rsquared < 0.90:
    for a in [np.max(c)>0.5]:
        model=smf.ols("Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=c2).fit()
        (a,_)=model.get_influence().cooks_distance
        a
        np.argmax(a) , np.max(a)
        c2=c2.drop(c2.index[[np.argmax(a)]],axis=0).reset_index(drop=True)
        c2
    else:
        final_model=smf.ols("Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=c2).fit()
        final_model.rsquared , final_model.aic
        print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8778445878599779
# Thus model accuracy is improved to 0.8851845904421739
# Thus model accuracy is improved to 0.8894191849749752
# Thus model accuracy is improved to 0.8914204825569461
# Thus model accuracy is improved to 0.8921467826162199
# Thus model accuracy is improved to 0.8934037497368835
# Thus model accuracy is improved to 0.8944954473640402
# Thus model accuracy is improved to 0.8958333530393431
# Thus model accuracy is improved to 0.8966334481080778
# Thus model accuracy is improved to 0.8941835374074523
# Thus model accuracy is improved to 0.8951069956497651
# Thus model accuracy is improved to 0.8965514940097824
# Thus model accuracy is improved to 0.8971531368893257
# Thus model accuracy is improved to 0.8979680072945878
# Thus model accuracy is improved to 0.8975421185310549
# Thus model accuracy is improved to 0.8970095523065386
# Thus model accuracy is improved to 0.8965434597967323
# ...

# %% [markdown]
# ## final model accuracy

# %%
final_model.rsquared*100
# Out:
# 90.0376253231856

# %%
c2
# Out:
#       Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13750         23  72937  90  2000      3      5            210    1165
# 1     14950         26  48000  90  2000      3      5            210    1165
# 2     13750         30  38500  90  2000      3      5            210    1170
# 3     12950         32  61000  90  2000      3      5            210    1170
# 4     16900         27  94612  90  2000      3      5            210    1245
# ...     ...        ...    ...  ..   ...    ...    ...            ...     ...
# 1325   8450         80  23000  86  1300      3      5             69    1015
# 1326   7500         69  20544  86  1300      3      5             69    1025
# 1327  10845         72  19000  86  1300      3      5             69    1015
# 1328   8500         71  17016  86  1300      3      5             69    1015
# 1329   7250         70  16916  86  1300      3      5             69    1015
#
# [1330 rows x 9 columns]

# %% [markdown]
# ## Predicting for new data

# %%
new=pd.DataFrame({'Age_08_04':10,"KM":40000,"HP":80,"cc":1300,"Doors":4,"Gears":5,"Quarterly_Tax":69,"Weight":1050},index=[0])
new
# Out:
#    Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0         10  40000  80  1300      4      5             69    1050

# %%
final_model.predict(new)
# Out:
# 0    16020.447822
# dtype: float64

# %% [markdown]
# ## Prediction of the price for the new data is 16020 ,with 90% accuracy
